# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movie= pd.read_csv(r"C:\Users\raavi\Desktop\NIT\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
type(movie)
# Out:
# pandas.core.frame.DataFrame

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movie)
# Out:
# 559

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns =['Film', 'Genre', 'Critic Ratings ', 'Audience Ratings',
       'Budget million', 'Year']

# %%
movie.head()
# Out:
#                     Film      Genre  Critic Ratings   Audience Ratings  \
# 0  (500) Days of Summer      Comedy               87                81
# 1            10,000 B.C.  Adventure                9                44
# 2             12 Rounds      Action               30                52
# 3              127 Hours  Adventure               93                84
# 4              17 Again      Comedy               55                70
#
#    Budget million  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie.Film= movie.Film.astype('category')
movie.Genre= movie.Genre.astype('category')
movie.Year= movie.Year.astype('category')

# %%
movie.describe()
# Out:
#        Critic Ratings   Audience Ratings  Budget million
# count       559.000000        559.000000      559.000000
# mean         47.309481         58.744186       50.236136
# std          26.413091         16.826887       48.731817
# min           0.000000          0.000000        0.000000
# 25%          25.000000         47.000000       20.000000
# 50%          46.000000         58.000000       35.000000
# 75%          70.000000         72.000000       65.000000
# max          97.000000         96.000000      300.000000

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    category
#  2   Critic Ratings    559 non-null    int64
#  3   Audience Ratings  559 non-null    int64
#  4   Budget million    559 non-null    int64
#  5   Year              559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.describe()
# Out:
#        Critic Ratings   Audience Ratings  Budget million
# count       559.000000        559.000000      559.000000
# mean         47.309481         58.744186       50.236136
# std          26.413091         16.826887       48.731817
# min           0.000000          0.000000        0.000000
# 25%          25.000000         47.000000       20.000000
# 50%          46.000000         58.000000       35.000000
# 75%          70.000000         72.000000       65.000000
# max          97.000000         96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
movie.columns =['Film', 'Genre', 'CriticRatings', 'AudienceRatings',
       'Budgetmillion', 'Year']

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budgetmillion',
#        'Year'],
#       dtype='object')

# %%
Vis= sns.jointplot(data = movie, x='CriticRatings', y='AudienceRatings', kind='scatter')

# %%
Vis= sns.jointplot(data = movie, x='CriticRatings', y='AudienceRatings', kind='kde')

# %%
Vis= sns.jointplot(data = movie, x='CriticRatings', y='AudienceRatings', kind='hex')

# %%
Vis= sns.jointplot(data = movie, x='CriticRatings', y='AudienceRatings', kind='reg')

# %%
vis= sns.distplot(movie['CriticRatings'])

# %%
vis= sns.distplot(movie['AudienceRatings'])

# %%
vis= sns.displot(movie['CriticRatings'])

# %%
vis= sns.set_style("darkgrid")
vis

# %%
vis

# %%
vis2= sns.distplot(movie.AudienceRatings, bins=16)

# %%
sns.set_style('whitegrid')
vis2= sns.distplot(movie.AudienceRatings, bins=16)

# %%
vis2= plt.hist(movie.AudienceRatings, bins=20)

# %%
plt.hist(movie.Budgetmillion)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movie[movie.Genre == 'Comedy'].Budgetmillion)
# Out:
# (array([39., 55., 37., 17., 18.,  4.,  1.,  0.,  0.,  1.]),
#  array([  0. ,  17.5,  35. ,  52.5,  70. ,  87.5, 105. , 122.5, 140. ,
#         157.5, 175. ]),
#  <BarContainer object of 10 artists>)

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
plt.hist(movie[movie.Genre == 'Comedy'].Budgetmillion, bins=25)
plt.hist(movie[movie.Genre == 'Adventure'].Budgetmillion, bins=25)
plt.hist(movie[movie.Genre == 'Action'].Budgetmillion, bins=25)
plt.legend()

# %%
plt.hist([movie[movie.Genre == 'Action'].Budgetmillion,\
          movie[movie.Genre == 'Drama'].Budgetmillion, \
          movie[movie.Genre == 'Thriller'].Budgetmillion, \
          movie[movie.Genre == 'Comedy'].Budgetmillion],
         bins = 20, stacked = True)
plt.show()

# %%
for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.set_style('whitegrid')
vis1 = sns.lmplot(data=movie, x='CriticRatings', y='AudienceRatings', fit_reg=True)

# %%
sns.set_style('whitegrid')
vis1 = sns.lmplot(data=movie, x='CriticRatings', y='AudienceRatings', fit_reg=True, hue='Genre')

# %%
sns.set_style('whitegrid')
vis1 = sns.lmplot(data=movie, x='CriticRatings', y='AudienceRatings', fit_reg=True, hue='Genre',height =3,aspect=1 )

# %%
k1 = sns.kdeplot(movie.CriticRatings)

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
f, ax = plt.subplots(3,3, figsize =(12,6))

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(movie.Budgetmillion)
k2 = sns.kdeplot(movie.CriticRatings)
plt.legend()

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
sns.boxplot(data= movie, x='Genre', y='CriticRatings')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRatings'>

# %%
sns.violinplot(data= movie, x='Genre', y='CriticRatings')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRatings'>

# %%
d=sns.boxplot(data = movie[movie.Genre =='Comedy'], x='year', y='CriticRatings')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 d=sns.boxplot(data = movie[movie.Genre =='Comedy'], x='year', y='CriticRatings')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)   1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
# ...

# %%
plt.scatter(movie.CriticRatings,movie.AudienceRatings)

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRatings', 'AudienceRatings' ) #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'Budgetmillion') #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movie.Budgetmillion, ax=axes[0,0])
k2 = sns.kdeplot(movie.Budgetmillion,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y = 'CriticRatings', ax=axes[1,0])

k4 = sns.kdeplot(movie.CriticRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movie.CriticRatings,cmap='Reds',ax = axes[1,1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 17
#      13 z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y = 'CriticRatings', ax=axes[1,0])
#      15 k4 = sns.kdeplot(movie.CriticRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
# ---> 17 k4b = sns.kdeplot(movie.CriticRatings,cmap='Reds',ax = axes[1,1])
#      19 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1701, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1697 if p.univariate:
#    1699     plot_kws = kwargs.copy()
# -> 1701     p.plot_univariate_density(
#    1702         multiple=multiple,
# ...

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(movie.Budgetmillion,movie.AudienceRatings, \
                 shade = True, shade_lowest=True,cmp = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(movie.Budgetmillion, movie.AudienceRatings, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 10
#       7 f, axes = plt.subplots (2,2, figsize = (15,15))
#       9 #plot [0,0]
# ---> 10 k1 = sns.kdeplot(movie.Budgetmillion,movie.AudienceRatings, \
#      11                  shade = True, shade_lowest=True,cmp = 'inferno', \
#      12                  ax = axes[0,0])
#      13 k1b = sns.kdeplot(movie.Budgetmillion, movie.AudienceRatings, \
#      14                  cmap = 'cool',ax = axes[0,0])
#      16 #plot [0,1]
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# # Assistant
# The error occurs because the `kdeplot()` function in newer versions of Seaborn doesn't accept multiple positional arguments for x and y variables. Instead, it requires using named parameters.
#
# Would you like me to provide the corrected code?

# %%
# How can you style your dashboard using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# plot [0,0]
# Using consistent column names throughout the code
k1 = sns.kdeplot(x=movie.Budgetmillion, y=movie.AudienceRatings, 
                 shade=True, shade_lowest=True, cmap='inferno',
                 ax=axes[0,0])
k1b = sns.kdeplot(x=movie.Budgetmillion, y=movie.AudienceRatings, 
                 cmap='cool', ax=axes[0,0])

# plot [0,1]
# Changed CriticRating to CriticRatings for consistency
k2 = sns.kdeplot(x=movie.Budgetmillion, y=movie.CriticRatings,
                 shade=True, shade_lowest=True, cmap='inferno',
                 ax=axes[0,1])
k2b = sns.kdeplot(x=movie.Budgetmillion, y=movie.CriticRatings,
                  cmap='cool', ax=axes[0,1])

# plot[1,0]
z = sns.violinplot(data=movie[movie.Genre=='Drama'], 
                   x='Year', y='CriticRatings', ax=axes[1,0])  # Changed CriticRating to CriticRatings

# plot[1,1]
# Using consistent column names (CriticRatings and AudienceRatings)
k4 = sns.kdeplot(x=movie.CriticRatings, y=movie.AudienceRatings,
                 shade=True, shade_lowest=False, cmap='Blues_r', 
                 ax=axes[1,1])

k4b = sns.kdeplot(x=movie.CriticRatings, y=movie.AudienceRatings,
                  cmap='gist_gray_r', ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
